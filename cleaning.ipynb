# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df   =  pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Name'] = df['Name'].str.lower()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name'].isnull().value_counts()
# Out:
# Name
# False    889
# Name: count, dtype: int64

# %%
df['Name1'] =  df['Name'].str.split()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name1'] = df['Name'].str.replace('mr.', 'x')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# df['Name1'] = df['Name'].str.replace('mr.', 'x')
df['Name1'] = df['Name1'].str.replace(r"[()]", "", regex=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name1'] = df['Name1'].str.replace('"','')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df['Cabin'].isnull().value_counts())
print(df['Cabin'].value_counts())

print(df['Cabin'])
# Out:
# Cabin
# True     687
# False    204
# Name: count, dtype: int64
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'] = df['Cabin'].str.split().str[0]
df['Cabin'].value_counts()
# Out:
# Cabin
# G6      4
# F       4
# C23     4
# B96     4
# F33     3
#        ..
# E17     1
# A24     1
# C50     1
# B42     1
# C148    1
# Name: count, Length: 145, dtype: int64

# %%
df[df['Cabin'].str.startswith('F', na=False)].value_counts("Cabin")
# Out:
# Cabin
# F      4
# F2     3
# F33    3
# F4     2
# F38    1
# Name: count, dtype: int64

# %%
print(pd.crosstab(df['Pclass'], df['Deck']))
# Out:
# Deck     A   B   C   D   E  F  G  T
# Pclass
# 1       15  47  59  29  25  0  0  1
# 2        0   0   0   4   4  8  0  0
# 3        0   0   0   0   3  5  4  0

# %%
df_clean = df[df.notnull().all(axis=1)]
traning_drok =  df_clean['Cabin'].str[0]
traning_drok.value_counts()
# Out:
# Cabin
# C    51
# B    43
# D    31
# E    30
# A    12
# F    11
# G     4
# T     1
# Name: count, dtype: int64

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 6                              mccarthy, mr. timothy j    male  54.0      0
# 10                     sandstrom, miss. marguerite rut  female   4.0      1
# 11                            bonnell, miss. elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isnull().value_counts()
# Out:
# Age
# False    714
# True     177
# Name: count, dtype: int64

# %%
idex = df[df['Embarked'].isnull()].index

# %%
df = df.drop(index=idex)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                              Braund Mr Owen Harris    male  22.0      1
# 1    Cumings Mrs John Bradley Florence Briggs Thayer  female  38.0      1
# 2                               Heikkinen Miss Laina  female  26.0      0
# 3           Futrelle Mrs Jacques Heath Lily May Peel  female  35.0      1
# 4                             Allen Mr William Henry    male  35.0      0
# ..                                               ...     ...   ...    ...
# ...

# %%
df['Name'] = df['Name'].str.lower()

# %%
df['Name'] = df['Name'].str.strip()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name'] =  df['Name'].str.replace(r"[^\w\s]","",regex=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                              Braund Mr Owen Harris    male  22.0      1
# 1    Cumings Mrs John Bradley Florence Briggs Thayer  female  38.0      1
# 2                               Heikkinen Miss Laina  female  26.0      0
# 3           Futrelle Mrs Jacques Heath Lily May Peel  female  35.0      1
# 4                             Allen Mr William Henry    male  35.0      0
# ..                                               ...     ...   ...    ...
# ...

# %%
df['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 889, dtype: object

# %%
df_age =  df[['PassengerId','Survived','Pclass','Name','Sex','SibSp','Parch','Ticket','Fare','Embarked','Age']]

# %%
df_age = df_age.drop(columns=['PassengerId','Name','Ticket','Survived','Parch'])

# %%
df_age
# Out:
#      Pclass     Sex  SibSp     Fare Embarked   Age
# 0         3    male      1   7.2500        S  22.0
# 1         1  female      1  71.2833        C  38.0
# 2         3  female      0   7.9250        S  26.0
# 3         1  female      1  53.1000        S  35.0
# 4         3    male      0   8.0500        S  35.0
# ..      ...     ...    ...      ...      ...   ...
# 886       2    male      0  13.0000        S  27.0
# 887       1  female      0  30.0000        S  19.0
# 888       3  female      1  23.4500        S   NaN
# 889       1    male      0  30.0000        C  26.0
# 890       3    male      0   7.7500        Q  32.0
#
# [889 rows x 6 columns]

# %%
df_age['Ticket']  = df_age['Ticket'].str.strip()
df_age['Ticket']  = df_age['Ticket'].str.lower()
# Out:
# /tmp/ipykernel_5550/3640563751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age['Ticket']  = df_age['Ticket'].str.strip()
# /tmp/ipykernel_5550/3640563751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age['Ticket']  = df_age['Ticket'].str.lower()

# %%
df_age["prefix"] = df_age["Ticket"].str.extract(r"([A-Za-z./]+)")
df_age["ticket_nember"] =  df_age["Ticket"].str.extract(r'(\d+)$')

# %%
df_age["prefix"] = df_age["prefix"].fillna('unknown')
df_age["ticket_nember"] = df_age["ticket_nember"].fillna(0).astype(int)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_age['Name'] = le.fit_transform(df_age['Name'])
df_age['Sex'] = le.fit_transform(df_age['Sex'])
df_age['Ticket'] = le.fit_transform(df_age['Ticket'])
df_age['Embarked'] = le.fit_transform(df_age['Embarked'])
df_age['prefix'] = le.fit_transform(df_age['prefix'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[232], line 3
# ...

# %%
df_age = df_age.drop(columns=['PassengerId','Name','Ticket','Survived','Parch'])

# %%
df_age['Sex'] = le.fit_transform(df_age['Sex'])
df_age['Embarked'] = le.fit_transform(df_age['Embarked'])

# %%
predictors = ['Pclass','Sex','SibSp','Fare','Embarked']
x_traing =  df_age[df_age['Age'].notnull()][predictors]
y_traing =  df_age[df_age['Age'].notnull()]['Age']
x_testing =  df_age[df_age['Age'].isnull()][predictors]

# %%
x_testing
# Out:
#      Pclass  Sex  SibSp     Fare  Embarked
# 5         3    1      0   8.4583         1
# 17        2    1      0  13.0000         2
# 19        3    0      0   7.2250         0
# 26        3    1      0   7.2250         0
# 28        3    0      0   7.8792         1
# ..      ...  ...    ...      ...       ...
# 859       3    1      0   7.2292         0
# 863       3    0      8  69.5500         2
# 868       3    1      0   9.5000         2
# 878       3    1      0   7.8958         2
# 888       3    0      1  23.4500         2
#
# [177 rows x 5 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
model =  RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_traing, y_traing)
# Out:
# RandomForestRegressor(random_state=42)

# %%
predicted_ages = model.predict(x_testing)

# %%
predicted_ages
# Out:
# array([30.59586692, 31.83842118, 16.14108929, 32.04612121, 19.70133333,
#        27.16953548, 32.5331    , 22.01237698, 24.44493254, 31.63566984,
#        30.74032269, 36.38895833, 22.01237698, 10.8815    , 37.42864286,
#        37.99866667, 21.68995238, 27.16953548, 30.74032269, 20.98322619,
#        30.74032269, 30.74032269, 27.16953548, 30.56105919, 26.96      ,
#        30.74032269, 45.42603157, 17.59083333, 21.745     , 30.79328433,
#        25.3358802 , 12.24184127, 26.18066667, 53.93995238,  8.22466667,
#        15.70578571, 26.31479524, 44.97666667, 31.1775    , 45.42603157,
#        22.01237698, 12.24184127, 34.02235985, 27.16953548,  6.85384524,
#        21.48933333, 15.32183333, 31.1775    , 30.79328433, 31.28033333,
#        45.42603157, 22.01237698, 47.59816667, 22.01237698, 34.64448766,
#        56.59464286, 37.99866667, 44.72883333, 22.01237698, 17.0969881 ,
#        33.8265625 , 30.74032269, 32.04      , 12.24184127, 12.84020238,
# ...

# %%
import xgboost as xgb
model1 = xgb.XGBRegressor(
    n_estimators=100,   
    learning_rate=0.1,  
    max_depth=3,       
    random_state=42
)

# %%
model1.fit(x_traing, y_traing)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
predicted_ages_xgb = model1.predict(x_testing)

# %%
predicted_ages_xgb
# Out:
# array([29.119776, 32.689907, 17.532345, 27.32806 , 23.019686, 28.931404,
#        42.89731 , 26.692165, 24.670856, 24.99473 , 28.931404, 27.844105,
#        26.692165, 12.374772, 43.280006, 44.877216, 22.507929, 28.931404,
#        28.931404, 24.010725, 28.931404, 28.931404, 28.931404, 28.587914,
#        27.395693, 28.931404, 36.18419 , 18.97113 , 21.193323, 29.567562,
#        28.166153, 15.084297, 32.452126, 44.1721  ,  6.854881, 16.442234,
#        30.276115, 40.626575, 26.623852, 36.18419 , 26.692165, 15.084297,
#        33.370377, 28.931404,  7.701349, 24.151281, 20.703457, 26.623852,
#        29.567562, 34.913437, 36.18419 , 26.692165, 44.49537 , 26.692165,
#        35.505707, 44.1721  , 44.877216, 44.49537 , 26.692165, 17.9581  ,
#        31.217562, 28.931404, 32.827522, 15.084297, 16.50719 , 33.426743,
#        28.931404, 24.68814 , 48.988514, 27.32806 , 23.019686, 23.019686,
#        27.844105, 16.855782, 26.692165, 33.719467, 28.931404, 29.561153,
# ...

# %%
df_age
# Out:
#      Pclass  Sex  SibSp     Fare  Embarked   Age
# 0         3    1      1   7.2500         2  22.0
# 1         1    0      1  71.2833         0  38.0
# 2         3    0      0   7.9250         2  26.0
# 3         1    0      1  53.1000         2  35.0
# 4         3    1      0   8.0500         2  35.0
# ..      ...  ...    ...      ...       ...   ...
# 886       2    1      0  13.0000         2  27.0
# 887       1    0      0  30.0000         2  19.0
# 888       3    0      1  23.4500         2  26.0
# 889       1    1      0  30.0000         0  26.0
# 890       3    1      0   7.7500         1  32.0
#
# [889 rows x 6 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                              Braund Mr Owen Harris    male  22.0      1
# 1    Cumings Mrs John Bradley Florence Briggs Thayer  female  38.0      1
# 2                               Heikkinen Miss Laina  female  26.0      0
# 3           Futrelle Mrs Jacques Heath Lily May Peel  female  35.0      1
# 4                             Allen Mr William Henry    male  35.0      0
# ..                                               ...     ...   ...    ...
# ...

# %%
new_datset = df

# %%
predicted_ages_xgb = predicted_ages_xgb.astype(int)


new_datset.loc[new_datset['Age'].isnull(), 'Age'] = predicted_ages_xgb

# %%
new_datset['Cabin'] = new_datset['Cabin'].str.split().str[0]

# %%
new_datset['Cabin'] = new_datset['Cabin'].str[0]

# %%
new_datset['Cabin']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: Cabin, Length: 889, dtype: object

# %%
new_datset['Cabin'].isnull().value_counts()
# Out:
# Cabin
# True     687
# False    202
# Name: count, dtype: int64

# %%
new_datset['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    25.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 889, dtype: float64

# %%
df_age['Name'] = le.fit_transform(df_age['Name'])
df_age['Sex'] = le.fit_transform(df_age['Sex'])
df_age['Ticket'] = le.fit_transform(df_age['Ticket'])
df_age['Embarked'] = le.fit_transform(df_age['Embarked'])
df_age['prefix'] = le.fit_transform(df_age['prefix'])
